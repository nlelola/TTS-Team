# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import sklearn.metrics as metrics

# Visualization package imports
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv(
    "/Users/nandjillelola/Documents/GitHub/ML/Team ML/zips/city_temperature/city_temperature.csv"
)
# Out:
# /var/folders/9r/m3130z5s3rbc10_6scgfp5t00000gn/T/ipykernel_23386/3222458214.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/Users/nandjillelola/Documents/GitHub/ML/Team ML/zips/city_temperature/city_temperature.csv")

# %% [markdown]
# ### CLEAN DATA

# %% [markdown]
# Remove temperatures -99
# Years from 1995 - 2020
# Figure out what to do with state NaN
# Days over 31 and Months over 12
# Check spelling
#
# Data Cleaning
# Visulizations

# %%
data.head(10)
# Out:
#    Region  Country State     City  Month  Day  Year  AvgTemperature
# 0  Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1  Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2  Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3  Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4  Africa  Algeria   NaN  Algiers      1    5  1995            47.9
# 5  Africa  Algeria   NaN  Algiers      1    6  1995            48.7
# 6  Africa  Algeria   NaN  Algiers      1    7  1995            48.9
# 7  Africa  Algeria   NaN  Algiers      1    8  1995            49.1
# 8  Africa  Algeria   NaN  Algiers      1    9  1995            49.0
# 9  Africa  Algeria   NaN  Algiers      1   10  1995            51.9

# %%
data.dtypes
# Out:
# Region             object
# Country            object
# State              object
# City               object
# Month               int64
# Day                 int64
# Year                int64
# AvgTemperature    float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Region            0
# Country           0
# State             0
# City              0
# Month             0
# Day               0
# Year              0
# AvgTemperature    0
# dtype: int64

# %%
data["Day"].min()
# Out:
# 0

# %%
data["Month"].max()
# Out:
# 12

# %%
data = data.fillna("Not applicable")

# %%
data["State"].unique()
# Out:
# array(['Not applicable', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Maryland', 'Florida', 'Georgia', 'Hawaii',
#        'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Additional Territories'],
#       dtype=object)

# %%
clean_data = data[
    (data["Day"] >= 1) & (data["Year"] >= 1995) & (data["AvgTemperature"] > -98)
]

# %%
clean_data.groupby(["Country"])["AvgTemperature"].min()
# Out:
# Country
# Albania       24.9
# Algeria       33.3
# Argentina     35.3
# Australia     30.7
# Austria        3.8
#               ...
# Uzbekistan     3.8
# Venezuela     71.5
# Vietnam       44.7
# Yugoslavia     1.4
# Zambia        47.8
# Name: AvgTemperature, Length: 125, dtype: float64

# %%
clean_data.sort_values(by="AvgTemperature", ascending=True).head(0)
# Out:
#                 Region Country   State       City  Month  Day  Year  \
# 1499140  North America      US  Alaska  Fairbanks     12   31  1999
# 1498811  North America      US  Alaska  Fairbanks      2    5  1999
# 1503552  North America      US  Alaska  Fairbanks      1   29  2012
# 1499141  North America      US  Alaska  Fairbanks      1    1  2000
# 1498050  North America      US  Alaska  Fairbanks      1    5  1997
# 1498810  North America      US  Alaska  Fairbanks      2    4  1999
# 1501359  North America      US  Alaska  Fairbanks      1   27  2006
# 1499139  North America      US  Alaska  Fairbanks     12   30  1999
# 1499143  North America      US  Alaska  Fairbanks      1    3  2000
# 1499142  North America      US  Alaska  Fairbanks      1    2  2000
# 1499153  North America      US  Alaska  Fairbanks      1   13  2000
# 1503551  North America      US  Alaska  Fairbanks      1   28  2012
# 1498809  North America      US  Alaska  Fairbanks      2    3  1999
# ...
